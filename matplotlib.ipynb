# %% [markdown]
# <a href="https://colab.research.google.com/github/Man1exter/DataScienceBOOT/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.10.0'

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1,3,0.2)
x_sin = np.sin(x)
x_cos = np.cos(x)

plt.plot(x,x_sin)
plt.plot(x,x_cos)
